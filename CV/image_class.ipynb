# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
# flower_photo/
#   daisy/
#   dandelion/
#   roses/
#   sunflowers/
#   tulips/

# %%
import os

# %%
import pathlib

dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos.tar', origin=dataset_url, cache_subdir=os.getcwd(),extract=True)
data_dir = pathlib.Path(data_dir).with_suffix('')

# %% [markdown]
# for segmentation

# %% [markdown]
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)

# %% [markdown]
# same for train , test ,validation set

# %% [markdown]
# for classification

# %% [markdown]
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)

# %% [markdown]
# for detection

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# annotations as .txt file containing box coordinates of mask like
#
# 0
#
# 0.5752380952380952
#
# 0.4142857142857143
#
# 0.21714285714285714
#
# 0.3485714285714286
